# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
import os

PROJECT_ROOT = r"C:\Users\nicol\OneDrive\Bureau\Finance"
os.chdir(PROJECT_ROOT)

print("Current working directory:", os.getcwd())
# Out:
# Current working directory: C:\Users\nicol\OneDrive\Bureau\Finance

# %%
df = pd.read_csv("data/interim/market_clean.csv", index_col=0, parse_dates=True)
df.head(10)
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2015-01-05 00:00:00-05:00  2054.439941  2054.439941  2017.339966  2020.579956
# 2015-01-06 00:00:00-05:00  2022.150024  2030.250000  1992.439941  2002.609985
# 2015-01-07 00:00:00-05:00  2005.550049  2029.609985  2005.550049  2025.900024
# 2015-01-08 00:00:00-05:00  2030.609985  2064.080078  2030.609985  2062.139893
# 2015-01-09 00:00:00-05:00  2063.449951  2064.429932  2038.329956  2044.810059
# 2015-01-12 00:00:00-05:00  2046.130005  2049.300049  2022.579956  2028.260010
# 2015-01-13 00:00:00-05:00  2031.579956  2056.929932  2008.250000  2023.030029
# 2015-01-14 00:00:00-05:00  2018.400024  2018.400024  1988.439941  2011.270020
# 2015-01-15 00:00:00-05:00  2013.750000  2021.349976  1991.469971  1992.670044
# 2015-01-16 00:00:00-05:00  1992.250000  2020.459961  1988.119995  2019.420044
#
#                                Volume  log_return
# Date
# 2015-01-05 00:00:00-05:00  3799120000   -0.018447
# 2015-01-06 00:00:00-05:00  4460110000   -0.008933
# 2015-01-07 00:00:00-05:00  3805480000    0.011563
# 2015-01-08 00:00:00-05:00  3934010000    0.017730
# 2015-01-09 00:00:00-05:00  3364140000   -0.008439
# 2015-01-12 00:00:00-05:00  3456460000   -0.008127
# 2015-01-13 00:00:00-05:00  4107300000   -0.002582
# 2015-01-14 00:00:00-05:00  4378680000   -0.005830
# 2015-01-15 00:00:00-05:00  4276720000   -0.009291
# 2015-01-16 00:00:00-05:00  4056410000    0.013335

# %%
df["Close"].plot(title="Prix de clôture")
plt.show()

# %%
df["log_return"].plot(title="Rendements logarithmiques")
plt.show()
